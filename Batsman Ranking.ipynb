# %% [markdown]
# # This notebook is to find a formaular to calculate a rating for batsman.
#
# The Formular will first look something as below
#     Z = X1.C1 + X2.C2 + ... Xn.Cn
#     Where X are the player attributes ( Strikerate, Runs Scored, etc) and Cs are coefficients which represents the weights of the attributes.
#     These weights will be calculated by finding out how important a attribute is in defining an outcome for a match.

# %% [markdown]
# # 1. Calculating the Cs of the formular

# %%
#Import Libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.inspection import permutation_importance


#For Machine Learning Algorithms
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

# %%
pd.set_option('display.max_rows',5000)

# %%
df = pd.read_csv('/Users/thejakamahaulpatha/PycharmProjects/Cricket Project/Dataset/playermatchstatsl.csv')

# %%
df.shape
# Out:
# (2453, 16)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Player', 'Opposition', 'Ground', 'Inning',
#        'Batted', 'Runs', 'Balls Faced', 'Strick Rate', 'Not Out', 'TeamScore',
#        'TeamWicketslFallen', 'RPO', 'Overs', 'Result'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0        Date            Player Opposition   Ground  Inning  \
# 0           0  2017-10-20       A Dananjaya   Pakistan  Sharjah       1
# 1           1  2017-10-20  S Samarawickrama   Pakistan  Sharjah       1
# 2           2  2017-10-20   HDRL Thirimanne   Pakistan  Sharjah       1
# 3           3  2017-10-20       WU Tharanga   Pakistan  Sharjah       1
# 4           4  2017-10-20       NLTC Perera   Pakistan  Sharjah       1
#
#    Batted  Runs  Balls Faced  Strick Rate  Not Out  TeamScore  \
# 0    True    18           37        48.64    False        173
# 1    True     0            2         0.00    False        173
# 2    True    62           94        65.95    False        173
# 3    True     0            5         0.00    False        173
# 4    True     0            1         0.00    False        173
#
#    TeamWicketslFallen   RPO  Overs Result
# 0                  10  3.96   43.4   lost
# 1                  10  3.96   43.4   lost
# 2                  10  3.96   43.4   lost
# 3                  10  3.96   43.4   lost
# 4                  10  3.96   43.4   lost

# %%
df.tail()
# Out:
#       Unnamed: 0        Date         Player Opposition   Ground  Inning  \
# 2448        2448  2011-11-20  KC Sangakkara   Pakistan  Sharjah       2
# 2449        2449  2011-11-20    BMAJ Mendis   Pakistan  Sharjah       2
# 2450        2450  2011-11-20     TM Dilshan   Pakistan  Sharjah       2
# 2451        2451  2011-11-20     SL Malinga   Pakistan  Sharjah       2
# 2452        2452  2011-11-20   LD Chandimal   Pakistan  Sharjah       2
#
#       Batted  Runs  Balls Faced  Strick Rate  Not Out  TeamScore  \
# 2448    True    58          103        56.31    False        174
# 2449    True     2            7        28.57    False        174
# 2450    True    11           21        52.38    False        174
# 2451    True     4            6        66.66    False        174
# 2452    True    11           19        57.89    False        174
#
#       TeamWicketslFallen   RPO  Overs Result
# 2448                  10  3.83   45.2   lost
# 2449                  10  3.83   45.2   lost
# 2450                  10  3.83   45.2   lost
# 2451                  10  3.83   45.2   lost
# 2452                  10  3.83   45.2   lost

# %%
df.describe()
# Out:
#         Unnamed: 0       Inning         Runs  Balls Faced  Strick Rate  \
# count  2453.000000  2453.000000  2453.000000  2453.000000  2453.000000
# mean   1226.000000     1.439462    19.852018    23.964533    61.621553
# std     708.264428     0.496423    26.904726    29.451303    53.013985
# min       0.000000     1.000000     0.000000     0.000000     0.000000
# 25%     613.000000     1.000000     0.000000     3.000000     0.000000
# 50%    1226.000000     1.000000     8.000000    13.000000    62.500000
# 75%    1839.000000     2.000000    29.000000    34.000000    92.300000
# max    2452.000000     2.000000   174.000000   165.000000   400.000000
#
#          TeamScore  TeamWicketslFallen          RPO        Overs
# count  2453.000000         2453.000000  2453.000000  2453.000000
# mean    232.461883            7.663677     5.280269    43.737220
# std      66.903597            2.772765     0.974089     9.232592
# min      14.000000            0.000000     2.130000     3.200000
# 25%     193.000000            6.000000     4.590000    41.100000
# 50%     236.000000            9.000000     5.210000    48.300000
# 75%     286.000000           10.000000     6.000000    50.000000
# max     377.000000           10.000000     7.840000    50.000000

# %%
df['Result'].unique()
# Out:
# array(['lost', 'won', 'tied', 'n/r'], dtype=object)

# %%
# Let's remove the 'n/r' rows as this is not an outcome.

# %%
#Create a null array to include the indexes where 'n/r' exists
index = []
for i in range(len(df.index)):
    if df['Result'].values[i] == "n/r":
        index.append(i)

# Drop the rows where the 'n/r' is located
for j in index:
    df = df.drop(j)

# %%
#Let's check whether we have successfully dropped the 'n/r' values

# %%
df['Result'].unique()
# Out:
# array(['lost', 'won', 'tied'], dtype=object)

# %%
df.shape
# Out:
# (2387, 16)

# %%
# Now let's Remove the rows which the player had not batted as this will not make an impact for the Result.

# %%
#Create a null array to include the indexes where 'False' exists in 'Batted' Column
# index2 = []
# for i in range(len(df.index)):
#     if df['Batted'].values[i] == False:
#         index2.append(i)

# # Drop the rows where the 'False' is located
# for j in index2:
#     df = df.drop(j)

df.drop(df[df['Batted'] == False].index, inplace = True)

# %%
#Let's check whether we have successfully dropped the 'False' values in 'Batted' column

# %%
df['Batted'].unique()
# Out:
# array([ True])

# %%
df.shape
# Out:
# (2003, 16)

# %%
#Let's see which attributes makes sense to be taken for the calculation. 
#We can see the Runs , Strike Rate are key attributes relate to measuring batsman statistic

# %%
#Before fitting a model we need to change the nominal values of the Results to a integer values

# %%
# Let's replace these values with int
df['Result'].replace({"lost": int(0),"won":int(1),"tied":int(2)}, inplace=True)

# %%
# We will see the data types of the columns we have chose incase before fitting the model ('Runs','Strike Rate','Result')

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# Date                   object
# Player                 object
# Opposition             object
# Ground                 object
# Inning                  int64
# Batted                   bool
# Runs                    int64
# Balls Faced             int64
# Strick Rate           float64
# Not Out                  bool
# TeamScore               int64
# TeamWicketslFallen      int64
# RPO                   float64
# Overs                 float64
# Result                  int64
# dtype: object

# %%
# We will see the selected distributions through a histrogram

# %%
df['Result'].hist(figsize = (5, 5))
# Out:
# <AxesSubplot:>

# %%
df['Runs'].hist(figsize = (5, 5))
# Out:
# <AxesSubplot:>

# %%
# Now let's define our training and testing data sets from the data frame we have

# %%
x = df.iloc[:,[7,8]].values
y = df.iloc[:,15].values

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=1)

# %%
#We will see which algorithm gives the best results for predicting the outcome. 
#Creating a list with the models

models = []
models.append(('LR',LogisticRegression(solver='liblinear',multi_class='ovr')))
models.append(('LDA',LinearDiscriminantAnalysis()))
models.append(('KNN',KNeighborsClassifier()))
models.append(('CART',DecisionTreeClassifier()))
models.append(('NB',GaussianNB()))
models.append(('RFC',RandomForestClassifier()))
models.append(('SVM',SVC(gamma='auto')))

# %%
results = []
names = []

for name,model in models:
    kfold = StratifiedKFold(n_splits=2,random_state=1,shuffle=True)
    cv_results = cross_val_score(model,x_train,y_train,cv=kfold,scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    print('%s: %f (%f)'%(name,cv_results.mean(),cv_results.std()))
# Out:
# LR: 0.655792 (0.000666)
# LDA: 0.658455 (0.003329)
# KNN: 0.611851 (0.011318)
# CART: 0.580559 (0.001332)
# NB: 0.637150 (0.004660)
# RFC: 0.598535 (0.000666)
# SVM: 0.631158 (0.010652)

# %%
# We can see the Linear Discriminant Analysis gives a better result.

# %%
# Let's test the feature significance for this algorithm.

# %%
#Permutation Importance
#eli5 provides a way to compute feature importances for any black-box estimator by 
#measuring how score decreases when a feature is not available; the method is also 
#known as “permutation importance” or “Mean Decrease Accuracy (MDA)”.

# %%
model = LinearDiscriminantAnalysis()
# fit the model
model.fit(x_train, y_train)

# get importance
imps = permutation_importance(model, x_test, y_test)

importance = imps.importances_mean

# summarize feature importance
for i,v in enumerate(imps.importances_mean):
#     print(importance[i])
	print('Feature: %0d, Score: %.5f' % (i,v))
    
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: 0.08104
# Feature: 1, Score: 0.01637

# %% [markdown]
# #### C1 = 0.07784
# #### C2 = 0.01637
# #### So the forumula will look as   Z = (Average Runs)(0.07784) + (Average Strike Rate)(0.01637)

# %% [markdown]
# # Now let's find the rakings of players accordance with their batting score Z

# %%
#Calculating for a single player

playerName = 'KC Sangakkara'
totalRuns=0
strikeRate=0
count=0
batsmanRating = 0

for i in range(len(df.index)):
    if df['Player'].values[i] == playerName:
        totalRuns=totalRuns + df['Runs'].values[i]
        strikeRate = strikeRate + df['Strick Rate'].values[i]
        count = count+1
        
averageRuns = totalRuns/count    
averageStrikeRate = strikeRate/count    

print(averageRuns,averageStrikeRate)

batsmanRating = (averageRuns*0.07784)+(averageStrikeRate*0.01637)
print(batsmanRating)
# Out:
# 47.0377358490566 75.76264150943396
# 4.9016518

# %%
#Let's Find the same for all the players and put them in an array

# %%
playerNameArr = df['Player'].unique()

batsmanStat = pd.DataFrame({
    'Player Name':
    [],
    'Total Played Innings':
    [],
    'Total Runs':
    [],
    'averageRuns':
    [],
    'averageStrikeRate':
    [],
    'batsmanRating':
    []
})


for player in playerNameArr:
    
    playerName = player
    totalRuns=0
    strikeRate=0
    count=0
    batsmanRating = 0
    
    for i in range(len(df.index)):
        if df['Player'].values[i] == playerName:
            totalRuns=totalRuns + df['Runs'].values[i]
            strikeRate = strikeRate + df['Strick Rate'].values[i]
            count = count+1
    
    averageRuns = totalRuns/count    
    averageStrikeRate = strikeRate/count   
    batsmanRating = (averageRuns*0.07784)+(averageStrikeRate*0.01637)
    
#     batsmanStat['Player Name'].values[] 
    batsmanStat.loc[len(batsmanStat.index)] = [playerName,count,totalRuns,averageRuns,averageStrikeRate,batsmanRating]

# %%
print(batsmanStat)
# Out:
#          Player Name  Total Played Innings  Total Runs  averageRuns  \
# 0        A Dananjaya                  27.0       283.0    10.481481
# 1   S Samarawickrama                   7.0       138.0    19.714286
# 2    HDRL Thirimanne                 102.0      3138.0    30.764706
# 3        WU Tharanga                 104.0      2888.0    27.769231
# 4        NLTC Perera                 117.0      2135.0    18.247863
# 5         PLS Gamage                   5.0         4.0     0.800000
# 6       LD Chandimal                 127.0      3460.0    27.244094
# 7         RAS Lakmal                  45.0       241.0     5.355556
# 8        N Dickwella                  49.0      1571.0    32.061224
# 9    TAM Siriwardana                  23.0       486.0    21.130435
# 10        S Prasanna                  36.0       419.0    11.638889
# 11    MD Gunathilaka                  38.0      1426.0    37.526316
# 12     DAS Gunaratne                  24.0       536.0    22.333333
# 13      CBRLS Kumara                   6.0        17.0     2.833333
# 14        BKG Mendis                  72.0      2012.0    27.944444
# 15    PADLR Sandakan                  16.0        52.0     3.250000
# 16      SS Pathirana                  14.0       332.0    23.714286
# 17        SL Malinga                  81.0       351.0     4.333333
# 18       MDKJ Perera                  94.0      2798.0    29.765957
# 19         N Pradeep                  22.0        28.0     1.272727
# 20  DPMD Jayawardene                  96.0      3198.0    33.312500
# 21        RMS Eranga                  10.0        34.0     3.400000
# 22        AD Mathews                 153.0      4909.0    32.084967
# 23        TM Dilshan                 121.0      4734.0    39.123967
# 24   KMDN Kulasekara                  66.0       774.0    11.727273
# 25        BAW Mendis                  19.0        89.0     4.684211
# 26     KC Sangakkara                 106.0      4986.0    47.037736
# 27      PVD Chameera                  16.0       102.0     6.375000
# 28       PHT Kaushal                   1.0         0.0     0.000000
# 29     SMA Priyanjan                  20.0       420.0    21.000000
# 30     KDK Vithanage                   6.0        75.0    12.500000
# 31     CK Kapugedera                  12.0       181.0    15.083333
# 32       MF Maharoof                  10.0       120.0    12.000000
# 33        MD Shanaka                  19.0       488.0    25.684211
# 34       DM de Silva                  42.0       895.0    21.309524
# 35   NGRP Jayasuriya                   2.0        11.0     5.500000
# 36  GSNFG Jayasuriya                  10.0       195.0    19.500000
# 37   SMSM Senanayake                  32.0       276.0     8.625000
# 38      HMRKB Herath                  25.0       132.0     5.280000
# 39       BMAJ Mendis                  40.0       589.0    14.725000
# 40   FDM Karunaratne                  29.0       767.0    26.448276
# 41           I Udana                  15.0       190.0    12.666667
# 42      CRD Fernando                   4.0         0.0     0.000000
# 43       PC de Silva                   7.0        94.0    13.428571
# 44      SHT Kandamby                   5.0        56.0    11.200000
# 45     JDF Vandersay                   7.0        71.0    10.142857
# 46      MVT Fernando                   8.0        30.0     3.750000
# 47       LHD Dilhara                   1.0         6.0     6.000000
# 48    CKB Kulasekara                   3.0        38.0    12.666667
# 49          S Randiv                   7.0       124.0    17.714286
# 50     ST Jayasuriya                   1.0         2.0     2.000000
# 51       PARP Perera                   2.0        33.0    16.500000
# 52         AK Perera                   4.0        52.0    13.000000
# 53      BOP Fernando                   7.0       130.0    18.571429
# 54      WIA Fernando                  18.0       653.0    36.277778
# 55     LD Madushanka                   4.0        14.0     3.500000
# 56      PWH de Silva                  16.0       320.0    20.000000
# 57     DS Weerakkody                   3.0        73.0    24.333333
# 58       KMC Bandara                   1.0         1.0     1.000000
# 59         LPC Silva                   4.0        73.0    18.250000
# 60       KTGD Prasad                   9.0       112.0    12.444444
# 61        P Nissanka                   3.0        42.0    14.000000
# 62       KNA Bandara                   3.0       123.0    41.000000
# 63         MA Aponso                   7.0        10.0     1.428571
# 64    EMDY Munaweera                   2.0        15.0     7.500000
# 65   PM Pushpakumara                   2.0        11.0     5.500000
# 66        MDK Perera                   7.0        99.0    14.142857
# 67    DSK Madushanka                   1.0         7.0     7.000000
# 68       PHKD Mendis                   3.0        26.0     8.666667
# 69       CAK Rajitha                   3.0         0.0     0.000000
# 70         M Bhanuka                   1.0        36.0    36.000000
# 71         J Mubarak                   1.0         8.0     8.000000
#
#     averageStrikeRate  batsmanRating
# 0           69.348148       1.951108
# 1           49.464286       2.344290
# 2           64.185196       3.445436
# 3           72.382115       3.346452
# 4           94.577094       2.968641
# 5           12.500000       0.266897
# 6           66.346929       3.206780
# 7           52.859111       1.282180
# 8           91.354082       3.991112
# 9           93.178261       3.170121
# 10          68.751389       2.031431
# 11          80.296053       4.235495
# 12          74.003333       2.949861
# 13          33.673333       0.771779
# 14          72.089167       3.355295
# 15          35.803125       0.839077
# 16          81.602143       3.181747
# 17          71.256914       1.503782
# 18          80.954468       3.642207
# 19          31.704091       0.618065
# 20          73.600313       3.797882
# 21          44.248000       0.988996
# 22          76.648039       3.752222
# 23          79.897190       4.353327
# 24          78.333030       2.195163
# 25          70.958421       1.526208
# 26          75.762642       4.901652
# 27          58.602500       1.455553
# 28           0.000000       0.000000
# 29          81.470000       2.968304
# 30          91.296667       2.467526
# 31          62.697500       2.200445
# 32          87.453000       2.365686
# 33         115.635263       3.892208
# 34          72.647143       2.847967
# 35          50.000000       1.246620
# 36          64.131000       2.567704
# 37          88.047812       2.112713
# 38          60.365600       1.399180
# 39          82.736750       2.500595
# 40          62.435517       3.080803
# 41          81.738000       2.324024
# 42           0.000000       0.000000
# 43          80.155714       2.357429
# 44          46.170000       1.627611
# 45          35.117143       1.364388
# 46          53.501250       1.167715
# 47          27.270000       0.913450
# 48          45.433333       1.729717
# 49          67.607143       2.485609
# 50          50.000000       0.974180
# 51          28.945000       1.758190
# 52          49.882500       1.828497
# 53          49.470000       2.255424
# 54          79.957778       4.132771
# 55          61.250000       1.275103
# 56         106.098750       3.293637
# 57         102.720000       3.575633
# 58          33.330000       0.623452
# 59          39.582500       2.068546
# 60          99.794444       2.602311
# 61          74.306667       2.306160
# 62          73.976667       4.402438
# 63          37.557143       0.726010
# 64          62.915000       1.613719
# 65          58.330000       1.382982
# 66         104.571429       2.812714
# 67         116.660000       2.454604
# 68          46.793333       1.440620
# 69           0.000000       0.000000
# 70          92.300000       4.313191
# 71          53.330000       1.495732

# %%
batsmanStat.sort_values(by=['batsmanRating'],ascending=False)
# Out:
#          Player Name  Total Played Innings  Total Runs  averageRuns  \
# 26     KC Sangakkara                 106.0      4986.0    47.037736
# 62       KNA Bandara                   3.0       123.0    41.000000
# 23        TM Dilshan                 121.0      4734.0    39.123967
# 70         M Bhanuka                   1.0        36.0    36.000000
# 11    MD Gunathilaka                  38.0      1426.0    37.526316
# 54      WIA Fernando                  18.0       653.0    36.277778
# 8        N Dickwella                  49.0      1571.0    32.061224
# 33        MD Shanaka                  19.0       488.0    25.684211
# 20  DPMD Jayawardene                  96.0      3198.0    33.312500
# 22        AD Mathews                 153.0      4909.0    32.084967
# 18       MDKJ Perera                  94.0      2798.0    29.765957
# 57     DS Weerakkody                   3.0        73.0    24.333333
# 2    HDRL Thirimanne                 102.0      3138.0    30.764706
# 14        BKG Mendis                  72.0      2012.0    27.944444
# 3        WU Tharanga                 104.0      2888.0    27.769231
# 56      PWH de Silva                  16.0       320.0    20.000000
# 6       LD Chandimal                 127.0      3460.0    27.244094
# 16      SS Pathirana                  14.0       332.0    23.714286
# 9    TAM Siriwardana                  23.0       486.0    21.130435
# 40   FDM Karunaratne                  29.0       767.0    26.448276
# 4        NLTC Perera                 117.0      2135.0    18.247863
# 29     SMA Priyanjan                  20.0       420.0    21.000000
# 12     DAS Gunaratne                  24.0       536.0    22.333333
# 34       DM de Silva                  42.0       895.0    21.309524
# 66        MDK Perera                   7.0        99.0    14.142857
# 60       KTGD Prasad                   9.0       112.0    12.444444
# 36  GSNFG Jayasuriya                  10.0       195.0    19.500000
# 39       BMAJ Mendis                  40.0       589.0    14.725000
# 49          S Randiv                   7.0       124.0    17.714286
# 30     KDK Vithanage                   6.0        75.0    12.500000
# 67    DSK Madushanka                   1.0         7.0     7.000000
# 32       MF Maharoof                  10.0       120.0    12.000000
# 43       PC de Silva                   7.0        94.0    13.428571
# 1   S Samarawickrama                   7.0       138.0    19.714286
# 41           I Udana                  15.0       190.0    12.666667
# 61        P Nissanka                   3.0        42.0    14.000000
# 53      BOP Fernando                   7.0       130.0    18.571429
# 31     CK Kapugedera                  12.0       181.0    15.083333
# 24   KMDN Kulasekara                  66.0       774.0    11.727273
# 37   SMSM Senanayake                  32.0       276.0     8.625000
# 59         LPC Silva                   4.0        73.0    18.250000
# 10        S Prasanna                  36.0       419.0    11.638889
# 0        A Dananjaya                  27.0       283.0    10.481481
# 52         AK Perera                   4.0        52.0    13.000000
# 51       PARP Perera                   2.0        33.0    16.500000
# 48    CKB Kulasekara                   3.0        38.0    12.666667
# 44      SHT Kandamby                   5.0        56.0    11.200000
# 64    EMDY Munaweera                   2.0        15.0     7.500000
# 25        BAW Mendis                  19.0        89.0     4.684211
# 17        SL Malinga                  81.0       351.0     4.333333
# 71         J Mubarak                   1.0         8.0     8.000000
# 27      PVD Chameera                  16.0       102.0     6.375000
# 68       PHKD Mendis                   3.0        26.0     8.666667
# 38      HMRKB Herath                  25.0       132.0     5.280000
# 65   PM Pushpakumara                   2.0        11.0     5.500000
# 45     JDF Vandersay                   7.0        71.0    10.142857
# 7         RAS Lakmal                  45.0       241.0     5.355556
# 55     LD Madushanka                   4.0        14.0     3.500000
# 35   NGRP Jayasuriya                   2.0        11.0     5.500000
# 46      MVT Fernando                   8.0        30.0     3.750000
# 21        RMS Eranga                  10.0        34.0     3.400000
# 50     ST Jayasuriya                   1.0         2.0     2.000000
# 47       LHD Dilhara                   1.0         6.0     6.000000
# 15    PADLR Sandakan                  16.0        52.0     3.250000
# 13      CBRLS Kumara                   6.0        17.0     2.833333
# 63         MA Aponso                   7.0        10.0     1.428571
# 58       KMC Bandara                   1.0         1.0     1.000000
# 19         N Pradeep                  22.0        28.0     1.272727
# 5         PLS Gamage                   5.0         4.0     0.800000
# 28       PHT Kaushal                   1.0         0.0     0.000000
# 69       CAK Rajitha                   3.0         0.0     0.000000
# 42      CRD Fernando                   4.0         0.0     0.000000
#
#     averageStrikeRate  batsmanRating
# 26          75.762642       4.901652
# 62          73.976667       4.402438
# 23          79.897190       4.353327
# 70          92.300000       4.313191
# 11          80.296053       4.235495
# 54          79.957778       4.132771
# 8           91.354082       3.991112
# 33         115.635263       3.892208
# 20          73.600313       3.797882
# 22          76.648039       3.752222
# 18          80.954468       3.642207
# 57         102.720000       3.575633
# 2           64.185196       3.445436
# 14          72.089167       3.355295
# 3           72.382115       3.346452
# 56         106.098750       3.293637
# 6           66.346929       3.206780
# 16          81.602143       3.181747
# 9           93.178261       3.170121
# 40          62.435517       3.080803
# 4           94.577094       2.968641
# 29          81.470000       2.968304
# 12          74.003333       2.949861
# 34          72.647143       2.847967
# 66         104.571429       2.812714
# 60          99.794444       2.602311
# 36          64.131000       2.567704
# 39          82.736750       2.500595
# 49          67.607143       2.485609
# 30          91.296667       2.467526
# 67         116.660000       2.454604
# 32          87.453000       2.365686
# 43          80.155714       2.357429
# 1           49.464286       2.344290
# 41          81.738000       2.324024
# 61          74.306667       2.306160
# 53          49.470000       2.255424
# 31          62.697500       2.200445
# 24          78.333030       2.195163
# 37          88.047812       2.112713
# 59          39.582500       2.068546
# 10          68.751389       2.031431
# 0           69.348148       1.951108
# 52          49.882500       1.828497
# 51          28.945000       1.758190
# 48          45.433333       1.729717
# 44          46.170000       1.627611
# 64          62.915000       1.613719
# 25          70.958421       1.526208
# 17          71.256914       1.503782
# 71          53.330000       1.495732
# 27          58.602500       1.455553
# 68          46.793333       1.440620
# 38          60.365600       1.399180
# 65          58.330000       1.382982
# 45          35.117143       1.364388
# 7           52.859111       1.282180
# 55          61.250000       1.275103
# 35          50.000000       1.246620
# 46          53.501250       1.167715
# 21          44.248000       0.988996
# 50          50.000000       0.974180
# 47          27.270000       0.913450
# 15          35.803125       0.839077
# 13          33.673333       0.771779
# 63          37.557143       0.726010
# 58          33.330000       0.623452
# 19          31.704091       0.618065
# 5           12.500000       0.266897
# 28           0.000000       0.000000
# 69           0.000000       0.000000
# 42           0.000000       0.000000

# %%
#We need to find a way to take the total number of played innings into the consideration as you can see
#ones who has played less innings are better in maintaining the average as the risk is very low of getting out. 

#This topic will be for a nother day

# %%
#Let's Take the players who have atleast played more than 15 innings

# %%
batsmanStat2 = batsmanStat.loc[batsmanStat['Total Played Innings'] > 10]

# %%
batsmanStat2.sort_values(by=['batsmanRating'],ascending=False)
# Out:
#          Player Name  Total Played Innings  Total Runs  averageRuns  \
# 26     KC Sangakkara                 106.0      4986.0    47.037736
# 23        TM Dilshan                 121.0      4734.0    39.123967
# 11    MD Gunathilaka                  38.0      1426.0    37.526316
# 54      WIA Fernando                  18.0       653.0    36.277778
# 8        N Dickwella                  49.0      1571.0    32.061224
# 33        MD Shanaka                  19.0       488.0    25.684211
# 20  DPMD Jayawardene                  96.0      3198.0    33.312500
# 22        AD Mathews                 153.0      4909.0    32.084967
# 18       MDKJ Perera                  94.0      2798.0    29.765957
# 2    HDRL Thirimanne                 102.0      3138.0    30.764706
# 14        BKG Mendis                  72.0      2012.0    27.944444
# 3        WU Tharanga                 104.0      2888.0    27.769231
# 56      PWH de Silva                  16.0       320.0    20.000000
# 6       LD Chandimal                 127.0      3460.0    27.244094
# 16      SS Pathirana                  14.0       332.0    23.714286
# 9    TAM Siriwardana                  23.0       486.0    21.130435
# 40   FDM Karunaratne                  29.0       767.0    26.448276
# 4        NLTC Perera                 117.0      2135.0    18.247863
# 29     SMA Priyanjan                  20.0       420.0    21.000000
# 12     DAS Gunaratne                  24.0       536.0    22.333333
# 34       DM de Silva                  42.0       895.0    21.309524
# 39       BMAJ Mendis                  40.0       589.0    14.725000
# 41           I Udana                  15.0       190.0    12.666667
# 31     CK Kapugedera                  12.0       181.0    15.083333
# 24   KMDN Kulasekara                  66.0       774.0    11.727273
# 37   SMSM Senanayake                  32.0       276.0     8.625000
# 10        S Prasanna                  36.0       419.0    11.638889
# 0        A Dananjaya                  27.0       283.0    10.481481
# 25        BAW Mendis                  19.0        89.0     4.684211
# 17        SL Malinga                  81.0       351.0     4.333333
# 27      PVD Chameera                  16.0       102.0     6.375000
# 38      HMRKB Herath                  25.0       132.0     5.280000
# 7         RAS Lakmal                  45.0       241.0     5.355556
# 15    PADLR Sandakan                  16.0        52.0     3.250000
# 19         N Pradeep                  22.0        28.0     1.272727
#
#     averageStrikeRate  batsmanRating
# 26          75.762642       4.901652
# 23          79.897190       4.353327
# 11          80.296053       4.235495
# 54          79.957778       4.132771
# 8           91.354082       3.991112
# 33         115.635263       3.892208
# 20          73.600313       3.797882
# 22          76.648039       3.752222
# 18          80.954468       3.642207
# 2           64.185196       3.445436
# 14          72.089167       3.355295
# 3           72.382115       3.346452
# 56         106.098750       3.293637
# 6           66.346929       3.206780
# 16          81.602143       3.181747
# 9           93.178261       3.170121
# 40          62.435517       3.080803
# 4           94.577094       2.968641
# 29          81.470000       2.968304
# 12          74.003333       2.949861
# 34          72.647143       2.847967
# 39          82.736750       2.500595
# 41          81.738000       2.324024
# 31          62.697500       2.200445
# 24          78.333030       2.195163
# 37          88.047812       2.112713
# 10          68.751389       2.031431
# 0           69.348148       1.951108
# 25          70.958421       1.526208
# 17          71.256914       1.503782
# 27          58.602500       1.455553
# 38          60.365600       1.399180
# 7           52.859111       1.282180
# 15          35.803125       0.839077
# 19          31.704091       0.618065
